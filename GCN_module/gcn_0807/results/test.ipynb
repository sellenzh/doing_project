# %%
import matplotlib.pyplot as plt

files = ['train_loss.txt', 'val_loss.txt']
file =  open(files[0], 'r')
data = file.readlines()
loss, itr = [], []
i = 0
for num in data:
    itr.append(i)
    i += 1
    loss.append(float(num))
train_loss_per_half_epoch, train_itr_per = [], []
i, sum = 0, 0
while i < len(loss):
    sum += loss[i]
    i += 1
    if i % 63 == 0:
        sum /= 63
        train_loss_per_half_epoch.append(sum)
        train_itr_per.append(i / 63)

file =  open(files[1], 'r')
data = file.readlines()
loss, itr = [], []
i = 0
for num in data:
    itr.append(i)
    i += 1
    loss.append(float(num))
test_loss_per_half_epoch, test_itr_per = [], []
i, sum = 0, 0
while i < len(loss):
    sum += loss[i]
    i += 1
    if i % 63 == 0:
        sum /= 63
        test_loss_per_half_epoch.append(sum)
        test_itr_per.append(i / 63)


plt.figure()
plt.title('loss')
plt.plot(train_itr_per, train_loss_per_half_epoch, color='red', label='train_loss')
plt.plot(test_itr_per, test_loss_per_half_epoch, color='blue', label='val_loss')
plt.xlabel('x125 iters.')
plt.ylabel('loss_per_mean')
plt.legend()
plt.savefig('loss.jpg')
plt.show()

# %%
print(train_loss_per_half_epoch[-5:])
print(test_loss_per_half_epoch[-5:])
# Out:
# [0.4061605298111782, 0.3934363634712323, 0.39817284885116166, 0.4001515520853762, 0.4057552171340742]
# [0.5121917912825819, 0.5188621881611525, 0.5189347328695156, 0.5273229187473931, 0.5117829118073701]

# %%
import matplotlib.pyplot as plt

files = ['train_acc.txt', 'val_acc.txt']
file =  open(files[0], 'r')
data = file.readlines()
loss, itr = [], []
i = 0
for num in data:
    itr.append(i)
    i += 1
    loss.append(float(num))
train_loss_per_half_epoch, train_itr_per = [], []
i, sum = 0, 0
while i < len(loss):
    sum += loss[i]
    i += 1
    if i % 63 == 0:
        sum /= 63
        train_loss_per_half_epoch.append(sum)
        train_itr_per.append(i / 63)

file =  open(files[1], 'r')
data = file.readlines()
loss, itr = [], []
i = 0
for num in data:
    itr.append(i)
    i += 1
    loss.append(float(num))
test_loss_per_half_epoch, test_itr_per = [], []
i, sum = 0, 0
while i < len(loss):
    sum += loss[i]
    i += 1
    if i % 63 == 0:
        sum /= 63
        test_loss_per_half_epoch.append(sum)
        test_itr_per.append(i / 63)


plt.figure()
plt.title('acc')
plt.plot(train_itr_per, train_loss_per_half_epoch, color='red', label='train_acc')
plt.plot(test_itr_per, test_loss_per_half_epoch, color='blue', label='val_acc')
plt.xlabel('x125 iters.')
plt.ylabel('acc_per_mean')
plt.legend()
plt.savefig('acc.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt
files = ['test_loss.txt', 'test_acc.txt']
file =  open(files[0], 'r')
data = file.readlines()
loss, itr = [], []
i = 0
for num in data:
    itr.append(i)
    i += 1
    loss.append(float(num))
train_loss_per_half_epoch, train_itr_per = [], []
i, sum = 0, 0
while i < len(loss):
    sum += loss[i]
    i += 1
    if i % 3 == 0:
        sum /= 3
        train_loss_per_half_epoch.append(sum)
        train_itr_per.append(i / 3)

file =  open(files[1], 'r')
data = file.readlines()
loss, itr = [], []
i = 0
for num in data:
    itr.append(i)
    i += 1
    loss.append(float(num))
test_loss_per_half_epoch, test_itr_per = [], []
i, sum = 0, 0
while i < len(loss):
    sum += loss[i]
    i += 1
    if i % 3 == 0:
        sum /= 3
        test_loss_per_half_epoch.append(sum)
        test_itr_per.append(i / 3)


plt.figure()
plt.title('test')
plt.plot(train_itr_per, train_loss_per_half_epoch, color='red', label='test_loss')
plt.plot(test_itr_per, test_loss_per_half_epoch, color='blue', label='test_acc')
plt.xlabel('x500 iters.')
plt.ylabel('value')
plt.legend()
plt.savefig('test.jpg')
plt.show()

# %%
import torch
a = torch.randn(size=(2, 4, 62, 19))
b, c, t, v = a.size()
print(b, c, t, v)
# Out:
# 2 4 62 19
